# %% [markdown]
# # News Feed Reader
# Source: https://timesofindia.indiatimes.com/rss.cms

# %%
#Imports
import feedparser
import requests
from bs4 import BeautifulSoup
import hashlib
from datetime import date, datetime

import os
import shutil
import re
import time 
import html

# %% [markdown]
# ## Read Selected News feeds and extract detail content
#
# Below is the list of news feed avaialble in Times Of India. Some of the topic has been disabled to keep the news content size under controll and help train SLM faster

# %%
rss_feed_base_url = "https://timesofindia.indiatimes.com/"
rss_feed_urls = {
    "India":f"{rss_feed_base_url}/rssfeeds/-2128936835.cms",   # India
    "World":f"{rss_feed_base_url}/rssfeeds/296589292.cms",     # World
    #"NRI":f"{rss_feed_base_url}/rssfeeds/7098551.cms",       # NRI
    #"Business":f"{rss_feed_base_url}/rssfeeds/7098551.cms",       # Business
    #"US":f"{rss_feed_base_url}/rssfeeds_us/72258322.cms",   # US
    #"Crikcet":f"{rss_feed_base_url}/rssfeeds/54829575.cms",      # Cricket
    #"Sports":f"{rss_feed_base_url}/rssfeeds/4719148.cms",       # Sports
    #"Science":f"{rss_feed_base_url}/rssfeeds/-2128672765.cms",   # Scrience
    "Environment":f"{rss_feed_base_url}/rssfeeds/2647163.cms",       # Environment
    "Tech":f"{rss_feed_base_url}/rssfeeds/66949542.cms",      # Tech
    "Education":f"{rss_feed_base_url}/rssfeeds/913168846.cms",      # Education
    #"Entertainment":f"{rss_feed_base_url}/rssfeeds/1081479906.cms",     # Entertainment
    #"Life & style":f"{rss_feed_base_url}/rssfeeds/2886704.cms",        # Life & style
    #"Auto":f"{rss_feed_base_url}/rssfeeds/2886704.cms",        # Auto

}

# %%
# Function to fetch and parse RSS feed
def fetch_rss_feed(feed_url):
    feed = feedparser.parse(feed_url)
    return feed.entries

# Function to download content from a URL
def download_content(url):
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        # Extract main content (this may vary depending on the website structure)
        return soup.get_text()
    except Exception as e:
        print(f"Failed to fetch content from {url}: {e}")
        return None
    
# Function to create news content folders
def get_or_create_news_collecion_folder(topic="unk", base_folder_path="../data/news_content"):

    today_date = date.today()
    today_date_string = today_date.strftime("%Y%m%d")
    todays_news_folder =  f"{base_folder_path}/{today_date_string}"
    print(todays_news_folder)
    
    todays_news_file    =   f"{base_folder_path}/{today_date_string}/_{today_date_string}_all_news.txt"

    todays_news_topic_file    =   f"{base_folder_path}/{today_date_string}/_{today_date_string}_{topic}_news.txt"

    if not os.path.exists(todays_news_folder):
        os.makedirs(todays_news_folder)
        open(f"{todays_news_file}", "w").close()

    if not os.path.exists(todays_news_topic_file):
        open(f"{todays_news_topic_file}", "w").close()

    return todays_news_folder,todays_news_topic_file, todays_news_file

# %%
import sys
import json

def read_feed_and_download_content(topic, rss_url, rss_feed_count):
    news_items = fetch_rss_feed(rss_url)
    
    todays_news_folder, todays_news_topic_file, todays_news_file = get_or_create_news_collecion_folder(topic)

    soa_eoa_match = {}
    mcq_generation_instructions =[]
    for item in news_items:
        title = item.get("title", "No Title")
        
        summary = html.unescape(item.get("description", "No Description"))
        soup = BeautifulSoup(summary, 'html.parser')
        summary = soup.get_text(summary)

        link = item.get("link", None)
        print(f"Fetching: {title} => {link}")
        print(f"Description/Summary=>{summary}")
        if link:
            content = download_content(link)
            if content:

                try:
                    soa = " ".join(summary.split()[:10]) if summary else " ".join(title.split()[:10])
                    print("SOA=>",soa)
                    #soa_match = re.search(soa, content)
                    soa_matches = list(re.finditer(soa, content))
                    print("###SOA Matches:",len(soa_matches),":",soa_matches)
                    soa_match = soa_matches[len(soa_matches)-1]
                    if soa_match: content = content[soa_match.start():]
                    soa_eoa_match[f"{title}_eoa"]=soa_match
                except Exception as e:
                    print(e)
                    print("$$$$ Not able to process SOA for ", soa)
                    print("=== Ignoring the news content as of now ===")
                    continue
                    
                eoa = "End of Article"
                eoa_match = re.search(eoa, content)
                if eoa_match: content = content[:eoa_match.start()]
                soa_eoa_match[f"{title}_eoa"]=eoa_match


                # Save content to a file (optional)
                short_title = title[:50].replace(' ', '_')
                short_title = re.sub(r'[^A-Za-z0-9 _-]', "_", short_title).strip("_")
                epoch_sec =  int(time.time())
                filename = f"{todays_news_folder}/{topic}_{short_title}.txt"

                # Write news content to individual file
                with open(filename, "w", encoding="utf-8") as file:
                    file.write(f"{link}\n\n")
                    file.write(f"{title}\n\n")
                    file.write(f"{summary}\n\n")
                    file.write(f"{content}\n\n")

                # Aggregate news content topicwise
                with open(todays_news_topic_file, "a", encoding="utf-8") as file2:
                    file2.write(f"{title}\n\n")
                    file2.write(f"{summary}\n\n")
                    file2.write(f"{content}\n\n")

                # Aggregate news content in single file
                with open(todays_news_file, "a", encoding="utf-8") as file3:
                    file3.write(f"{title}\n\n")
                    file3.write(f"{summary}\n\n")
                    file3.write(f"{content}\n\n")

                print(f"Saved: {filename}")
                rss_feed_count[0] = rss_feed_count[0] + 1

                mcq_generation_instruction = {
                    "link":f"{link}",
                    "topic":f"{topic}",
                    "title":f"{title}",
                    "instruction":f"Generate a Multiple Choice Question with answer on the below {topic} input context.",
                    "input":f"{content}",
                    "output":"Question: \nOptions: \n[A]  \n[B]  \n[C] \n[D] \nCorrect Answer: "

                }
                mcq_generation_instructions.append(mcq_generation_instruction)
        else:
            print("No link found for this item.")

    return mcq_generation_instructions

# %%
rss_feed_urls_count = 0
rss_feed_count = [0]

mcq_generation_instructions = []
for topic, rss_feed_url in rss_feed_urls.items():
    print(topic,"=>",rss_feed_url)
    mcq_generation_instructions_= read_feed_and_download_content(topic,rss_feed_url, rss_feed_count)
    mcq_generation_instructions.extend(mcq_generation_instructions_)
    rss_feed_urls_count=rss_feed_urls_count+1

base_folder_path = "../data/news_content"
today_date = date.today()
today_date_string = today_date.strftime("%Y%m%d")
todays_news_folder =  f"{base_folder_path}/{today_date_string}"
print(todays_news_folder)

mcq_generation_instructions_file = f"{todays_news_folder}/__{today_date_string}_ca_mcqs_generation_instructions.json"
with open(mcq_generation_instructions_file, "a", encoding="utf-8") as f:
    json.dump(mcq_generation_instructions, f, indent=4)  # indent=4 makes it pretty
# Out:
# India => https://timesofindia.indiatimes.com//rssfeeds/-2128936835.cms
# ../data/news_content/20250823
# Fetching: J&K: Hizbul Mujahideen sleeper cell busted; OGW arrested, linked to cross-border terror handler => https://timesofindia.indiatimes.com/india/jk-hizb-ul-mujahideen-sleeper-cell-busted-ogw-arrested-linked-to-cross-border-terror-handler/articleshow/123470196.cms
# Description/Summary=>Jammu and Kashmir Police's SIA made a significant breakthrough by apprehending Altaf Hussain Wagay, an over-ground worker linked to Hizbul Mujahideen. Wagay, a resident of Shopian, was operating as a sleeper cell, facilitating terror activities in the region. Investigations revealed his direct links with a Hizb handler operating from across the border, orchestrating anti-national activities.
# SOA=> Jammu and Kashmir Police's SIA made a significant breakthrough by
# ###SOA Matches: 1 : [<re.Match object; span=(1381, 1446), match="Jammu and Kashmir Police's SIA made a significant>]
# Saved: ../data/news_content/20250823/India_J_K__Hizbul_Mujahideen_sleeper_cell_busted__OGW_ar.txt
# Fetching: India temporarily suspends most postal services to US; effective August 25 amid new customs order – Know what’s exempted from the ban => https://timesofindia.indiatimes.com/india/india-temporarily-suspends-most-postal-services-to-us-effective-august-25-amid-new-customs-order-know-whats-exempt-from-the-ban/articleshow/123469918.cms
# Description/Summary=>Effective August 25, 2025, the Department of Posts will temporarily suspend most international postal services to the US due to new customs regulations. The US Executive Order No. 14324 withdraws duty-free exemptions for goods valued up to $800, imposing duties on all goods except gift items under $100. The executive order also outlines new responsibilities for transport carriers and “qualified parties” authorized by US Customs and Border Protection (CBP).
# SOA=> Effective August 25, 2025, the Department of Posts will temporarily
# ###SOA Matches: 1 : [<re.Match object; span=(1495, 1562), match='Effective August 25, 2025, the Department of Post>]
# Saved: ../data/news_content/20250823/India_India_temporarily_suspends_most_postal_services_to.txt
# Fetching: Bill to remove jailed CM, PM, ministers: TMC terms JPC a 'farce'; won't nominate anyone for committee => https://timesofindia.indiatimes.com/india/bill-to-remove-jailed-cm-pm-ministers-tmc-terms-jpc-a-farce-wont-nominate-anyone-for-committee/articleshow/123469117.cms
# Description/Summary=>All India Trinamool Congress criticized the Joint Parliament Committee. The party declared it would not nominate anyone. This decision relates to bills concerning the removal of the Prime Minister and Chief Ministers. The bills were sent to the JPC after introduction in Lok Sabha. The party opposes the constitutional amendment bill. Tensions rose in Lok Sabha during the bill's introduction.
# SOA=> All India Trinamool Congress criticized the Joint Parliament Committee. The
# ###SOA Matches: 1 : [<re.Match object; span=(1400, 1475), match='All India Trinamool Congress criticized the Joint>]
# Saved: ../data/news_content/20250823/India_Bill_to_remove_jailed_CM__PM__ministers__TMC_terms.txt
# Fetching: 'Don't make it a causality': Jaishankar on India-China relations; says ties not dependent on US => https://timesofindia.indiatimes.com/india/dont-make-it-a-causality-jaishankar-on-india-china-relations-says-ties-not-dependent-on-us/articleshow/123468918.cms
# Description/Summary=>External Affairs Minister S Jaishankar stated that India's relationship with China should be considered independently from its ties with the United States. He cautioned against assuming a direct causal link between Washington's and Beijing's relations with New Delhi.
# SOA=> External Affairs Minister S Jaishankar stated that India's relationship with
# ###SOA Matches: 1 : [<re.Match object; span=(1381, 1457), match="External Affairs Minister S Jaishankar stated tha>]
# Saved: ../data/news_content/20250823/India_Don_t_make_it_a_causality___Jaishankar_on_India-C.txt
# Fetching: ‘Overlooking each other’s history’: Jaishankar takes swipe at US, Pakistan; reminds Bin Laden was found in Abbottabad => https://timesofindia.indiatimes.com/india/overlooking-each-others-history-jaishankar-takes-swipe-at-us-pakistan-reminds-bin-laden-was-found-in-abbottabad/articleshow/123468407.cms
# Description/Summary=>External affairs minister Dr S Jaishankar on Saturday criticised US–Pakistan for “overlooking each other's history,” recalling the Abbottabad raid that killed Osama bin Laden. He again rejected claims of US mediation in the post-Operation Sindoor ceasefire, stressing it was a direct India–Pakistan deal, and warned opposition against compromising farmers’ interests or India’s strategic autonomy.
# SOA=> External affairs minister Dr S Jaishankar on Saturday criticised US–Pakistan
# ###SOA Matches: 1 : [<re.Match object; span=(1447, 1523), match='External affairs minister Dr S Jaishankar on Satu>]
# Saved: ../data/news_content/20250823/India_Overlooking_each_other_s_history___Jaishankar_tak.txt
# Fetching: Illegal betting case: Karnataka Congress MLA KC Veerendra arrested after ED recovers massive hoard of cash; gold worth Rs 6 crore seized => https://timesofindia.indiatimes.com/india/illegal-betting-case-karnataka-congress-mla-arrested-with-massive-hoards-of-cash-gold-worth-6-crore-seized/articleshow/123468474.cms
# Description/Summary=>The Enforcement Directorate (ED) apprehended Karnataka Congress MLA KC Veerendra in Gangtok for allegedly leasing land for a casino. This arrest followed raids on 30 of his properties, uncovering Rs 12 crore in cash, including foreign currency, gold jewellery valued at Rs 6 crore, and 10 kgs of silver. The ED also froze 17 bank accounts and seized property documents.
# SOA=> The Enforcement Directorate (ED) apprehended Karnataka Congress MLA KC Veerendra
# ###SOA Matches: 0 : []
# list index out of range
# $$$$ Not able to process SOA for  The Enforcement Directorate (ED) apprehended Karnataka Congress MLA KC Veerendra
# === Ignoring the news content as of now ===
# Fetching: ‘You messed up!’: Mallikarjun Kharge slams PM Modi on economic ‘reforms’; tells BJP to pick ‘real data’ => https://timesofindia.indiatimes.com/india/you-messed-up-mallikarjun-kharge-slams-pm-modi-on-economic-reforms-tells-bjp-to-pick-real-data/articleshow/123468317.cms
# Description/Summary=>Congress President Mallikarjun Kharge has strongly criticized Prime Minister Modi's economic reforms, citing concerns over unemployment and declining wages. This critique follows PM Modi's inauguration of key infrastructure projects in Bihar and Kolkata, including a bridge, metro lines, and the Amrit Bharat Express.
# SOA=> Congress President Mallikarjun Kharge has strongly criticized Prime Minister Modi's
# ###SOA Matches: 1 : [<re.Match object; span=(1436, 1519), match="Congress President Mallikarjun Kharge has strongl>]
# Saved: ../data/news_content/20250823/India_You_messed_up____Mallikarjun_Kharge_slams_PM_Modi.txt
# Fetching: MCD & few ABC centres relocating sterilised dogs, allege animal lovers => https://timesofindia.indiatimes.com/india/mcd-few-abc-centres-relocating-sterilised-dogs-allege-animal-lovers/articleshow/123468379.cms
# Description/Summary=>
# SOA=> MCD & few ABC centres relocating sterilised dogs, allege animal
# ###SOA Matches: 4 : [<re.Match object; span=(0, 63), match='MCD & few ABC centres relocating sterilised dogs,>, <re.Match object; span=(653, 716), match='MCD & few ABC centres relocating sterilised dogs,>, <re.Match object; span=(1175, 1238), match='MCD & few ABC centres relocating sterilised dogs,>, <re.Match object; span=(5985, 6048), match='MCD & few ABC centres relocating sterilised dogs,>]
# Saved: ../data/news_content/20250823/India_MCD___few_ABC_centres_relocating_sterilised_dogs.txt
# Fetching: 'We have reached Moon and Mars': PM Modi greets the nation on National Space Day; recalls meeting with Shubhanshu Shukla => https://timesofindia.indiatimes.com/india/we-have-reached-moon-and-mars-pm-modi-greets-the-nation-on-national-space-day-recalls-meeting-with-shubhanshu-shukla/articleshow/123466876.cms
# Description/Summary=>Prime Minister Modi addressed the nation on National Space Day, celebrating India's space achievements and the accomplishments of its scientists and astronauts. He emphasized India's rapid progress in space technology, including the development of semi-cryogenic engines.
# SOA=> Prime Minister Modi addressed the nation on National Space Day,
# ###SOA Matches: 1 : [<re.Match object; span=(1456, 1519), match='Prime Minister Modi addressed the nation on Natio>]
# Saved: ../data/news_content/20250823/India_We_have_reached_Moon_and_Mars___PM_Modi_greets_th.txt
# Fetching: Bank fraud case: FIR registered against Anil Ambani; CBI raids premises linked to RCOM => https://timesofindia.indiatimes.com/india/bank-fraud-case-cbi-raids-sites-linked-to-anil-ambani-fir-registered/articleshow/123466944.cms
# Description/Summary=>The CBI raided premises linked to Reliance Communications and Anil Ambani concerning a suspected large-scale bank fraud, following an FIR registration. This action follows the ED's questioning of Ambani regarding a money laundering probe involving over Rs 17,000 crore in bank loan frauds.
# SOA=> The CBI raided premises linked to Reliance Communications and Anil
# ###SOA Matches: 1 : [<re.Match object; span=(1393, 1459), match='The CBI raided premises linked to Reliance Commun>]
# Saved: ../data/news_content/20250823/India_Bank_fraud_case__FIR_registered_against_Anil_Amban.txt
# Fetching: 'Spoiled brat': Rijiju's veiled attack at Rahul over 'vote chori' charge; shares CSDS apology => https://timesofindia.indiatimes.com/india/spoiled-brat-rijijus-veiled-attack-at-rahul-over-vote-chori-charge-shares-csds-apology/articleshow/123466012.cms
# Description/Summary=>Union Minister Kiren Rijiju criticized Rahul Gandhi's "vote chori" charge, referencing a CSDS psephologist's apology for a data mishap. Rijiju questioned Gandhi's credibility, accusing him of public lies and demanding an apology. Gandhi escalated his accusations against the BJP, alleging vote theft and accusing the Election Commission of complicity in undermining citizens' voting rights during a rally in Bhagalpur.
# SOA=> Union Minister Kiren Rijiju criticized Rahul Gandhi's "vote chori" charge,
# ###SOA Matches: 1 : [<re.Match object; span=(1414, 1488), match='Union Minister Kiren Rijiju criticized Rahul Gand>]
# Saved: ../data/news_content/20250823/India_Spoiled_brat___Rijiju_s_veiled_attack_at_Rahul_ov.txt
# Fetching: SIR row: Amartya Sen raises concern over revision; claims it risks 'disenfranchising' poor people => https://timesofindia.indiatimes.com/india/sir-row-amartya-sen-raises-concern-over-revision-claims-it-risks-disenfranchising-poor-people/articleshow/123465728.cms
# Description/Summary=>Amartya Sen voiced concerns that Bihar's electoral roll revision could disenfranchise the poor due to strict documentation requirements. The Supreme Court questioned the lack of political party involvement in correcting voter deletions during the revision. The court allowed online claim submissions with Aadhaar or other documents, seeking status reports from political parties by September 8.
# SOA=> Amartya Sen voiced concerns that Bihar's electoral roll revision could
# ###SOA Matches: 1 : [<re.Match object; span=(1426, 1496), match="Amartya Sen voiced concerns that Bihar's electora>]
# Saved: ../data/news_content/20250823/India_SIR_row__Amartya_Sen_raises_concern_over_revision.txt
# Fetching: Who is Sergio Gor? Trump nominates close aide as US Ambassador to India; replaces Eric Garcetti => https://timesofindia.indiatimes.com/india/who-is-sergio-gor-trump-nominates-close-aide-as-us-ambassador-to-india-replaces-eric-garcetti/articleshow/123464829.cms
# Description/Summary=>
# SOA=> Who is Sergio Gor? Trump nominates close aide as US
# ###SOA Matches: 0 : []
# list index out of range
# $$$$ Not able to process SOA for  Who is Sergio Gor? Trump nominates close aide as US
# === Ignoring the news content as of now ===
# Fetching: VL Kantha Rao is new water resources secy => https://timesofindia.indiatimes.com/india/vl-kantha-rao-is-new-water-resources-secy/articleshow/123463186.cms
# Description/Summary=>
# SOA=> VL Kantha Rao is new water resources secy
# ###SOA Matches: 5 : [<re.Match object; span=(0, 41), match='VL Kantha Rao is new water resources secy'>, <re.Match object; span=(624, 665), match='VL Kantha Rao is new water resources secy'>, <re.Match object; span=(1117, 1158), match='VL Kantha Rao is new water resources secy'>, <re.Match object; span=(4705, 4746), match='VL Kantha Rao is new water resources secy'>, <re.Match object; span=(10095, 10136), match='VL Kantha Rao is new water resources secy'>]
# Saved: ../data/news_content/20250823/India_VL_Kantha_Rao_is_new_water_resources_secy.txt
# Fetching: Activists welcome SC order on strays, but flag concerns => https://timesofindia.indiatimes.com/india/activists-welcome-sc-order-on-strays-but-flag-concerns/articleshow/123463168.cms
# Description/Summary=>
# SOA=> Activists welcome SC order on strays, but flag concerns
# ###SOA Matches: 4 : [<re.Match object; span=(0, 55), match='Activists welcome SC order on strays, but flag co>, <re.Match object; span=(638, 693), match='Activists welcome SC order on strays, but flag co>, <re.Match object; span=(1145, 1200), match='Activists welcome SC order on strays, but flag co>, <re.Match object; span=(6602, 6657), match='Activists welcome SC order on strays, but flag co>]
# Saved: ../data/news_content/20250823/India_Activists_welcome_SC_order_on_strays__but_flag_con.txt
# Fetching: IAS officers body slams 'personal attacks' on CEC & family by oppn => https://timesofindia.indiatimes.com/india/ias-officers-body-slams-personal-attacks-on-cec-family-by-oppn/articleshow/123463147.cms
# Description/Summary=>
# SOA=> IAS officers body slams 'personal attacks' on CEC & family
# ###SOA Matches: 4 : [<re.Match object; span=(0, 58), match="IAS officers body slams 'personal attacks' on CEC>, <re.Match object; span=(649, 707), match="IAS officers body slams 'personal attacks' on CEC>, <re.Match object; span=(1167, 1225), match="IAS officers body slams 'personal attacks' on CEC>, <re.Match object; span=(5677, 5735), match="IAS officers body slams 'personal attacks' on CEC>]
# Saved: ../data/news_content/20250823/India_IAS_officers_body_slams__personal_attacks__on_CEC.txt
# Fetching: Since 2014, theme of self-reliance has been a leitmotif of Modi's I-Day speeches => https://timesofindia.indiatimes.com/india/since-2014-theme-of-self-reliance-has-been-a-leitmotif-of-modis-i-day-speeches/articleshow/123463122.cms
# Description/Summary=>
# SOA=> Since 2014, theme of self-reliance has been a leitmotif of
# ###SOA Matches: 4 : [<re.Match object; span=(0, 58), match='Since 2014, theme of self-reliance has been a lei>, <re.Match object; span=(663, 721), match='Since 2014, theme of self-reliance has been a lei>, <re.Match object; span=(1195, 1253), match='Since 2014, theme of self-reliance has been a lei>, <re.Match object; span=(7229, 7287), match='Since 2014, theme of self-reliance has been a lei>]
# Saved: ../data/news_content/20250823/India_Since_2014__theme_of_self-reliance_has_been_a_leit.txt
# Fetching: India developing world-class infra at reduced cost, says Gadkari => https://timesofindia.indiatimes.com/india/india-developing-world-class-infra-at-reduced-cost-says-gadkari/articleshow/123463106.cms
# Description/Summary=>
# SOA=> India developing world-class infra at reduced cost, says Gadkari
# ###SOA Matches: 4 : [<re.Match object; span=(0, 64), match='India developing world-class infra at reduced cos>, <re.Match object; span=(647, 711), match='India developing world-class infra at reduced cos>, <re.Match object; span=(1163, 1227), match='India developing world-class infra at reduced cos>, <re.Match object; span=(5807, 5871), match='India developing world-class infra at reduced cos>]
# Saved: ../data/news_content/20250823/India_India_developing_world-class_infra_at_reduced_cost.txt
# Fetching: Many in US worried Trump is alienating allies, says Kerry => https://timesofindia.indiatimes.com/india/many-in-us-worried-trump-is-alienating-allies-says-kerry/articleshow/123463078.cms
# Description/Summary=>
# SOA=> Many in US worried Trump is alienating allies, says Kerry
# ###SOA Matches: 3 : [<re.Match object; span=(0, 57), match='Many in US worried Trump is alienating allies, sa>, <re.Match object; span=(640, 697), match='Many in US worried Trump is alienating allies, sa>, <re.Match object; span=(1149, 1206), match='Many in US worried Trump is alienating allies, sa>]
# Saved: ../data/news_content/20250823/India_Many_in_US_worried_Trump_is_alienating_allies__say.txt
# World => https://timesofindia.indiatimes.com//rssfeeds/296589292.cms
# ../data/news_content/20250823
# Fetching: Qatar Media Corporation and Al Jazeera Media Institute sign deal for joint training and media development => https://timesofindia.indiatimes.com/world/middle-east/qatar-media-corporation-and-al-jazeera-media-institute-sign-deal-for-joint-training-and-media-development/articleshow/123470188.cms
# Description/Summary=>Qatar Media Corporation and Al Jazeera Media Institute have signed a strategic agreement to develop specialised media training programmes, enhance production capabilities, and build national media talent. The partnership includes practical training in Al Jazeera’s studios, expert workshops, and exclusive support for QMC staff, aiming to align Qatar’s media sector with international standards and future industry demands.
# SOA=> Qatar Media Corporation and Al Jazeera Media Institute have signed
# ###SOA Matches: 1 : [<re.Match object; span=(968, 1034), match='Qatar Media Corporation and Al Jazeera Media Inst>]
# Saved: ../data/news_content/20250823/World_Qatar_Media_Corporation_and_Al_Jazeera_Media_Insti.txt
# Fetching: Russia-Ukraine conflict: Moscow captures 2 villages in Donetsk region; advances towards Ukrainian logistics base => https://timesofindia.indiatimes.com/world/rest-of-world/russia-ukraine-conflict-moscow-captures-2-villages-in-donetsk-region-advances-towards-ukrainian-logistics-base/articleshow/123469985.cms
# Description/Summary=>Russian forces have intensified their military campaign in Ukraine's Donetsk region, claiming the capture of Sredneye and Kleban-Byk. This advance brings Russian troops closer to Kostyantynivka, a strategically important town on the route to Kramatorsk. Kramatorsk serves as a vital logistics hub for Ukrainian forces, potentially disrupting supply lines if the advance continues.
# SOA=> Russian forces have intensified their military campaign in Ukraine's Donetsk
# ###SOA Matches: 1 : [<re.Match object; span=(986, 1062), match="Russian forces have intensified their military ca>]
# Saved: ../data/news_content/20250823/World_Russia-Ukraine_conflict__Moscow_captures_2_village.txt
# Fetching: Racist Berlin street name to change after legal battle => https://timesofindia.indiatimes.com/world/europe/racist-berlin-street-name-to-change-after-legal-battle/articleshow/123469759.cms
# Description/Summary=>Berlin's Mohrenstrasse, a street with a racist name rooted in Germany's colonial past, was slated to be renamed after Anton Wilhelm Amo, the first African-born scholar to earn a European doctorate. Despite years of lobbying and legal battles, residents initially blocked the change, but the courts ultimately upheld the renaming.
# SOA=> Berlin's Mohrenstrasse, a street with a racist name rooted in
# ###SOA Matches: 1 : [<re.Match object; span=(778, 839), match="Berlin's Mohrenstrasse, a street with a racist na>]
# Saved: ../data/news_content/20250823/World_Racist_Berlin_street_name_to_change_after_legal_ba.txt
# Fetching: Oman’s hotel revenues rose 18% in the first six months of 2025, with tourist arrivals reaching 1.14 million => https://timesofindia.indiatimes.com/world/middle-east/omans-hotel-revenues-rose-18-in-the-first-six-months-of-2025-with-tourist-arrivals-reaching-1-14-million/articleshow/123468167.cms
# Description/Summary=>Oman's hospitality sector thrived in the first half of 2025, witnessing an 18% surge in hotel revenues alongside a 1.14 million increase in tourist arrivals. This growth is attributed to strategic tourism development, enhanced infrastructure, and effective marketing initiatives. The nation's Vision 2040 plan aims to further boost tourism, supported by substantial investments in new resorts and projects.
# SOA=> Oman's hospitality sector thrived in the first half of 2025,
# ###SOA Matches: 1 : [<re.Match object; span=(974, 1034), match="Oman's hospitality sector thrived in the first ha>]
# Saved: ../data/news_content/20250823/World_Oman_s_hotel_revenues_rose_18__in_the_first_six_mo.txt
# Fetching: 15 Emirati healthcare professionals to be honoured at UAE’s largest Health Awards 2025 after rigorous evaluation process => https://timesofindia.indiatimes.com/world/middle-east/15-emirati-healthcare-professionals-to-be-honoured-at-uaes-largest-health-awards-2025-after-rigorous-evaluation-process/articleshow/123469061.cms
# Description/Summary=>The Health Awards 2025 will implement a fully independent evaluation process for all nominations to ensure transparency and merit-based recognition. A multi-stage review, including screening, verification, and jury assessment, will determine winners across 46 categories. The move reinforces the awards' credibility, with submissions open until 20 September ahead of the event on 9 October in Dubai.
# SOA=> The Health Awards 2025 will implement a fully independent evaluation
# ###SOA Matches: 1 : [<re.Match object; span=(1013, 1081), match='The Health Awards 2025 will implement a fully ind>]
# Saved: ../data/news_content/20250823/World_15_Emirati_healthcare_professionals_to_be_honoured.txt
# Fetching: Is Africa becoming the US's dumping ground of migrants? => https://timesofindia.indiatimes.com/world/rest-of-world/is-africa-becoming-the-uss-dumping-ground-of-migrants/articleshow/123468630.cms
# Description/Summary=>Under President Trump's immigration policies, the US is deporting migrants to African nations, including Uganda, Eswatini, and South Sudan, despite concerns over human rights and the capacity of these countries to host more refugees. These deals, framed as temporary arrangements, have sparked controversy and raised questions about the benefits for the host nations, with Nigeria rejecting the proposal outright.
# SOA=> Under President Trump's immigration policies, the US is deporting migrants
# ###SOA Matches: 1 : [<re.Match object; span=(788, 862), match="Under President Trump's immigration policies, the>]
# Saved: ../data/news_content/20250823/World_Is_Africa_becoming_the_US_s_dumping_ground_of_migr.txt
# Fetching: Saudi Arabia’s Crown Prince Mohammed bin Salman donates blood to launch annual national blood donation campaign => https://timesofindia.indiatimes.com/world/middle-east/saudi-arabias-crown-prince-mohammed-bin-salman-donates-blood-to-launch-annual-national-blood-donation-campaign/articleshow/123467219.cms
# Description/Summary=>Crown Prince Mohammed bin Salman donated blood to launch Saudi Arabia’s annual national campaign promoting voluntary donation. The initiative aims for 100% voluntary blood supply and aligns with Vision 2030 goals. Officials praised the gesture as a humanitarian example, with over 800,000 donors in 2024. Health leaders linked it to broader efforts, including organ donation and COVID-19 vaccination.
# SOA=> Crown Prince Mohammed bin Salman donated blood to launch Saudi
# ###SOA Matches: 1 : [<re.Match object; span=(986, 1048), match='Crown Prince Mohammed bin Salman donated blood to>]
# Saved: ../data/news_content/20250823/World_Saudi_Arabia_s_Crown_Prince_Mohammed_bin_Salman_do.txt
# Fetching: Adidas reps apologize to Mexican artisans over sandals => https://timesofindia.indiatimes.com/world/rest-of-world/adidas-reps-apologize-to-mexican-artisans-over-sandals/articleshow/123467739.cms
# Description/Summary=>Adidas has apologized to the Indigenous community of Villa Hidalgo Yalalag in Oaxaca, Mexico, for culturally appropriating their traditional huarache sandal design in their "Oaxaca Slip-On" shoe. Executives delivered the apology in person, acknowledging the discomfort caused and pledging future collaboration. The controversy drew national attention, with President Claudia Sheinbaum advocating for stronger protections against the exploitation of Indigenous culture.
# SOA=> Adidas has apologized to the Indigenous community of Villa Hidalgo
# ###SOA Matches: 1 : [<re.Match object; span=(785, 851), match='Adidas has apologized to the Indigenous community>]
# Saved: ../data/news_content/20250823/World_Adidas_reps_apologize_to_Mexican_artisans_over_san.txt
# Fetching: Save big: Qatar Rail launches 365-day Metropass with unlimited rides and early bird discount => https://timesofindia.indiatimes.com/world/middle-east/save-big-qatar-rail-launches-365-day-metropass-with-unlimited-rides-and-early-bird-discount/articleshow/123466573.cms
# Description/Summary=>Doha Metro unveils a yearly Metropass. It costs QR 990. Passengers enjoy unlimited rides on Doha Metro and Lusail Tram. An early bird promotion offers a 20% discount. Pre-booking is available at the Back to School event. Vouchers can be redeemed in September 2025. This pass benefits daily commuters, students, and families. It promotes sustainable urban mobility in Qatar.
# SOA=> Doha Metro unveils a yearly Metropass. It costs QR 990.
# ###SOA Matches: 1 : [<re.Match object; span=(929, 984), match='Doha Metro unveils a yearly Metropass. It costs Q>]
# Saved: ../data/news_content/20250823/World_Save_big__Qatar_Rail_launches_365-day_Metropass_wi.txt
# Fetching: Roblox blocked in Kuwait amid rising concerns on children’s online safety => https://timesofindia.indiatimes.com/world/middle-east/roblox-blocked-in-kuwait-amid-rising-concerns-on-childrens-online-safety/articleshow/123467384.cms
# Description/Summary=>Kuwait has temporarily blocked Roblox due to rising concerns about child safety, following complaints of harmful content and exploitation. The decision comes amid warnings from parents and organizations regarding unsafe practices impacting young users. Authorities aim to negotiate with Roblox to ensure robust child protection measures and content moderation before lifting the ban.
# SOA=> Kuwait has temporarily blocked Roblox due to rising concerns about
# ###SOA Matches: 1 : [<re.Match object; span=(872, 938), match='Kuwait has temporarily blocked Roblox due to risi>]
# Saved: ../data/news_content/20250823/World_Roblox_blocked_in_Kuwait_amid_rising_concerns_on_c.txt
# Fetching: US envoy to India: Trump picks Sergio Gor. Why did Musk call him ‘a snake’ once? => https://timesofindia.indiatimes.com/world/us/us-envoy-to-india-donald-trump-picks-sergio-gor-why-did-elon-musk-call-him-a-snake-once/articleshow/123467743.cms
# Description/Summary=>Sergio Gor, a close aide to Donald Trump, has been nominated as the US Ambassador to India, sparking controversy due to past clashes with Elon Musk. Musk previously labeled Gor a "snake" and accused him of legal violations related to security clearance paperwork. Trump defended Gor, emphasizing his loyalty and importance to US-India relations amidst ongoing tariff disputes.
# SOA=> Sergio Gor, a close aide to Donald Trump, has been
# ###SOA Matches: 1 : [<re.Match object; span=(996, 1046), match='Sergio Gor, a close aide to Donald Trump, has bee>]
# Saved: ../data/news_content/20250823/World_US_envoy_to_India__Trump_picks_Sergio_Gor__Why_did.txt
# Fetching: ‘I am the one who got them out’: Trump claims less than 20 Israeli hostages still alive, says ‘couple of them not around any longer’ => https://timesofindia.indiatimes.com/world/us/i-am-the-one-who-got-them-out-trump-claims-less-than-20-israeli-hostages-still-alive-says-couple-of-them-not-around-any-longer/articleshow/123466752.cms
# Description/Summary=>Donald Trump's claim that fewer than 20 hostages remain alive in Gaza has sparked outrage from families and a swift denial from Israel's hostage negotiator. Trump asserted credit for releasing "hundreds" of hostages, a figure disputed by facts. Israeli officials maintain that 50 hostages are still held, with 20 believed to be alive, while denouncing Hamas's "extortion" tactics.
# SOA=> Donald Trump's claim that fewer than 20 hostages remain alive
# ###SOA Matches: 1 : [<re.Match object; span=(1108, 1169), match="Donald Trump's claim that fewer than 20 hostages >]
# Saved: ../data/news_content/20250823/World_I_am_the_one_who_got_them_out___Trump_claims_less.txt
# Fetching: From VIP suites to in-flight luxury: Find out how Emirates Is going all out to celebrate 14 Years as US open’s official airline => https://timesofindia.indiatimes.com/world/middle-east/from-vip-suites-to-in-flight-luxury-find-out-how-emirates-is-going-all-out-to-celebrate-14-years-as-us-opens-official-airline/articleshow/123467312.cms
# Description/Summary=>Emirates returns as the Official Airline of the US Open for the 14th year, combining luxury hospitality, youth tennis outreach, and in-flight fan experiences. Highlights include its VIP suite at Arthur Ashe Stadium, Arthur Ashe Kids’ Day giveaways, youth clinics with tennis legends, live match broadcasts onboard, themed menus, and exclusive Skywards member access.
# SOA=> Emirates returns as the Official Airline of the US Open
# ###SOA Matches: 1 : [<re.Match object; span=(1034, 1089), match='Emirates returns as the Official Airline of the U>]
# Saved: ../data/news_content/20250823/World_From_VIP_suites_to_in-flight_luxury__Find_out_how.txt
# Fetching: San Francisco: ICE clashes with protesters; charge knife-wielding suspect => https://timesofindia.indiatimes.com/world/us/san-francisco-ice-clashes-with-protesters-charge-knife-wielding-suspect/articleshow/123465458.cms
# Description/Summary=>A mob ambushed ICE officers in San Francisco, with one assailant, Adrian Guerrero, threatening to stab an officer and target his family. Guerrero, armed with a knife, allegedly slashed a government vehicle's tire before confronting the agents, resulting in charges of assault and property destruction.
# SOA=> A mob ambushed ICE officers in San Francisco, with one
# ###SOA Matches: 1 : [<re.Match object; span=(931, 985), match='A mob ambushed ICE officers in San Francisco, wit>]
# Saved: ../data/news_content/20250823/World_San_Francisco__ICE_clashes_with_protesters__charge.txt
# Fetching: Mass crackdown: 168 illegal workers arrested as Kuwait sharpens labour law enforcement => https://timesofindia.indiatimes.com/world/middle-east/mass-crackdown-168-illegal-workers-arrested-as-kuwait-sharpens-labour-law-enforcement/articleshow/123465904.cms
# Description/Summary=>Kuwait's Public Authority for Manpower, in collaboration with the General Directorate of Residence Affairs Investigations, has arrested 168 workers in Mutlaa for violating labour and residency laws. The crackdown included 130 illegal domestic workers and 38 private sector workers. Authorities are intensifying inspections to regulate the labour market and ensure compliance, with strict legal repercussions for non-compliant employers.
# SOA=> Kuwait's Public Authority for Manpower, in collaboration with the General
# ###SOA Matches: 1 : [<re.Match object; span=(932, 1005), match="Kuwait's Public Authority for Manpower, in collab>]
# Saved: ../data/news_content/20250823/World_Mass_crackdown__168_illegal_workers_arrested_as_Ku.txt
# Fetching: Back-to-School season: Dubai RTA tightens school bus safety rules for 2025–2026 academic year => https://timesofindia.indiatimes.com/world/middle-east/back-to-school-season-dubai-rta-tightens-school-bus-safety-rules-for-20252026-academic-year/articleshow/123466046.cms
# Description/Summary=>Dubai's RTA is enhancing student safety for the 2025-2026 academic year by implementing stricter guidelines and safety checks for school buses. The Back-to-School program includes intensive driver training, advanced safety technologies, and improved parent communication. These measures aim to ensure secure and comfortable commutes for all students, reinforcing RTA's commitment to seamless mobility.
# SOA=> Dubai's RTA is enhancing student safety for the 2025-2026 academic
# ###SOA Matches: 1 : [<re.Match object; span=(977, 1043), match="Dubai's RTA is enhancing student safety for the 2>]
# Saved: ../data/news_content/20250823/World_Back-to-School_season__Dubai_RTA_tightens_school_b.txt
# Fetching: Day after Erik, Lyle Menendez’s freedom bid denied; board issues three-year denial => https://timesofindia.indiatimes.com/world/us/menendez-brothers-parole-day-after-erik-lyles-freedom-bid-denied-board-issues-three-year-denial/articleshow/123466120.cms
# Description/Summary=>Lyle Menendez, convicted with his brother Erik for the 1989 murder of their parents, has been denied parole after his first hearing since resentencing. The decision follows a similar rejection for Erik, keeping both brothers incarcerated despite their reduced sentences.
# SOA=> Lyle Menendez, convicted with his brother Erik for the 1989
# ###SOA Matches: 1 : [<re.Match object; span=(1038, 1097), match='Lyle Menendez, convicted with his brother Erik fo>]
# Saved: ../data/news_content/20250823/World_Day_after_Erik__Lyle_Menendez_s_freedom_bid_denied.txt
# Fetching: Watch: Massive fire erupts at Louisiana auto supply plant; residents ordered to evacuate => https://timesofindia.indiatimes.com/world/us/watch-massive-fire-erupts-at-louisiana-auto-supply-plant-residents-ordered-to-evacuate/articleshow/123464414.cms
# Description/Summary=>A major explosion and fire erupted at Smitty’s Supply in Louisiana, a lubricant and automotive fluid manufacturer, prompting immediate evacuations within a one-mile radius, including an elementary school. Multiple agencies, including the EPA and LDEQ, are responding to the incident, monitoring air quality, and providing support.
# SOA=> A major explosion and fire erupted at Smitty’s Supply in
# ###SOA Matches: 1 : [<re.Match object; span=(1026, 1082), match='A major explosion and fire erupted at Smitty’s Su>]
# Saved: ../data/news_content/20250823/World_Watch__Massive_fire_erupts_at_Louisiana_auto_suppl.txt
# Fetching: Driver distracted? New York City tour bus crash kills five – Indians among passengers => https://timesofindia.indiatimes.com/world/us/driver-distracted-new-york-city-tour-bus-crash-kills-five-indians-among-passengers/articleshow/123464317.cms
# Description/Summary=>A tour bus accident on Interstate 90 near Pembroke, New York, resulted in five fatalities and numerous injuries. The bus, carrying 54 people from Niagara Falls to New York City, overturned when the driver became distracted and lost control. Most passengers were of Indian, Chinese, and Filipino descent. Investigations are ongoing, with distraction identified as the likely cause.
# SOA=> A tour bus accident on Interstate 90 near Pembroke, New
# ###SOA Matches: 1 : [<re.Match object; span=(1009, 1064), match='A tour bus accident on Interstate 90 near Pembrok>]
# Saved: ../data/news_content/20250823/World_Driver_distracted__New_York_City_tour_bus_crash_ki.txt
# Fetching: Chicago Mayor hits out at Trump’s threat to send in National Guard => https://timesofindia.indiatimes.com/world/us/uncalled-for-and-unsound-chicago-mayor-hits-out-at-donald-trumps-threat-to-send-in-national-guard-cites-crime-drop-legal-limits/articleshow/123464187.cms
# Description/Summary=>
# SOA=> Chicago Mayor hits out at Trump’s threat to send in
# ###SOA Matches: 0 : []
# list index out of range
# $$$$ Not able to process SOA for  Chicago Mayor hits out at Trump’s threat to send in
# === Ignoring the news content as of now ===
# Environment => https://timesofindia.indiatimes.com//rssfeeds/2647163.cms
# ../data/news_content/20250823
# Fetching: Bumpy skies: How climate change increases air turbulence => https://timesofindia.indiatimes.com/home/environment/bumpy-skies-how-climate-change-increases-air-turbulence/articleshow/123459638.cms
# Description/Summary=>The seatbelt sign pings on, trays rattle, drinks slosh in their glasses.  Some airlines are moving towards strategies involving passengers wearing seatbelts more often, such as ending cabin service earlier.
# SOA=> The seatbelt sign pings on, trays rattle, drinks slosh in
# ###SOA Matches: 2 : [<re.Match object; span=(1514, 1571), match='The seatbelt sign pings on, trays rattle, drinks >, <re.Match object; span=(1721, 1778), match='The seatbelt sign pings on, trays rattle, drinks >]
# Saved: ../data/news_content/20250823/Environment_Bumpy_skies__How_climate_change_increases_air_turb.txt
# Fetching: A ‘spot’ of hope: Chital returns to Faridabad Aravalis => https://timesofindia.indiatimes.com/city/gurgaon/a-spot-of-hope-chital-returns-to-faridabad-aravalis/articleshow/123440256.cms
# Description/Summary=>
# SOA=> A ‘spot’ of hope: Chital returns to Faridabad Aravalis
# ###SOA Matches: 3 : [<re.Match object; span=(0, 54), match='A ‘spot’ of hope: Chital returns to Faridabad Ara>, <re.Match object; span=(814, 868), match='A ‘spot’ of hope: Chital returns to Faridabad Ara>, <re.Match object; span=(1233, 1287), match='A ‘spot’ of hope: Chital returns to Faridabad Ara>]
# Saved: ../data/news_content/20250823/Environment_A__spot__of_hope__Chital_returns_to_Faridabad_Arav.txt
# Fetching: Record EU wildfires burnt more than 1 million hectares in 2025: AFP analysis => https://timesofindia.indiatimes.com/home/environment/record-eu-wildfires-burnt-more-than-1-million-hectares-in-2025-afp-analysis/articleshow/123435107.cms
# Description/Summary=>Wildfires have so far ravaged more than one million hectares (2.5 million acres)analysis of data from the European Forest Fire Information System (EFFIS). This calculation is based on a total compiled by AFP from estimates by country by EFFIS, at a time when Spain and Portugal are still battling wildfires.
# SOA=> Wildfires have so far ravaged more than one million hectares
# ###SOA Matches: 2 : [<re.Match object; span=(1574, 1634), match='Wildfires have so far ravaged more than one milli>, <re.Match object; span=(1883, 1943), match='Wildfires have so far ravaged more than one milli>]
# Saved: ../data/news_content/20250823/Environment_Record_EU_wildfires_burnt_more_than_1_million_hect.txt
# Fetching: Antarctic ice loss could have 'catastrophic' impact => https://timesofindia.indiatimes.com/home/environment/antarctic-ice-loss-could-have-catastrophic-impact/articleshow/123426541.cms
# Description/Summary=>
# SOA=> Antarctic ice loss could have 'catastrophic' impact
# ###SOA Matches: 3 : [<re.Match object; span=(0, 51), match="Antarctic ice loss could have 'catastrophic' impa>, <re.Match object; span=(1334, 1385), match="Antarctic ice loss could have 'catastrophic' impa>, <re.Match object; span=(1385, 1436), match="Antarctic ice loss could have 'catastrophic' impa>]
# Saved: ../data/news_content/20250823/Environment_Antarctic_ice_loss_could_have__catastrophic__impac.txt
# Fetching: Spain wildfires burn record territory this year: Monitor => https://timesofindia.indiatimes.com/world/europe/spain-wildfires-burn-record-territory-this-year-monitor/articleshow/123375753.cms
# Description/Summary=>Deadly wildfires ravaging Spain have burnt the equivalent of nearly half a million football fields this year, setting a new record for the country, a European monitor said Monday. Portugal set the European record of 563,000 hectares scorched in 2017, when 119 people were killed.
# SOA=> Deadly wildfires ravaging Spain have burnt the equivalent of nearly
# ###SOA Matches: 2 : [<re.Match object; span=(830, 897), match='Deadly wildfires ravaging Spain have burnt the eq>, <re.Match object; span=(1139, 1206), match='Deadly wildfires ravaging Spain have burnt the eq>]
# Saved: ../data/news_content/20250823/Environment_Spain_wildfires_burn_record_territory_this_year__M.txt
# Fetching: Watch: Floods batter Pakistan; homes swamped, roads submerged => https://timesofindia.indiatimes.com/world/pakistan/watch-floods-batter-pakistan-homes-swamped-roads-submerged/articleshow/123355040.cms
# Description/Summary=>Devastating flash floods in Pakistan have claimed at least 657 lives, including many children, with Khyber Pakhtunkhwa province being the hardest hit. Entire villages have been wiped out, mass burials are underway, and hundreds remain missing as rescue efforts continue amidst warnings of more torrential rains. The scale of destruction is immense, with eyewitnesses recounting homes and vehicles swept away.
# SOA=> Devastating flash floods in Pakistan have claimed at least 657
# ###SOA Matches: 1 : [<re.Match object; span=(866, 928), match='Devastating flash floods in Pakistan have claimed>]
# Saved: ../data/news_content/20250823/Environment_Watch__Floods_batter_Pakistan__homes_swamped__road.txt
# Fetching: Cloudburst in Kathua triggers landslide, flash floods: 7 dead, trains disrupted, CM announces ex-gratia – top developments => https://timesofindia.indiatimes.com/india/cloudburst-in-kathua-triggers-landslide-flash-floods-7-dead-trains-disrupted-cm-announces-ex-gratia-top-developments/articleshow/123344275.cms
# Description/Summary=>A devastating cloudburst in Jammu and Kashmir's Kathua district has claimed seven lives, triggering landslides and flash floods. The deluge washed away roads, damaged homes, and disrupted train services on the Jammu-Pathankot line. Rescue operations are underway, with the Army, NDRF, and SDRF assisting victims.
# SOA=> A devastating cloudburst in Jammu and Kashmir's Kathua district has
# ###SOA Matches: 1 : [<re.Match object; span=(1408, 1475), match="A devastating cloudburst in Jammu and Kashmir's K>]
# Saved: ../data/news_content/20250823/Environment_Cloudburst_in_Kathua_triggers_landslide__flash_flo.txt
# Fetching: A cruel summer as record wildfires scorch Europe => https://timesofindia.indiatimes.com/world/europe/a-cruel-summer-as-record-wildfires-scorch-europe/articleshow/123329434.cms
# Description/Summary=>Wildfires continue to test firefighters and locals across Europe as droughts and heatwaves turn regions into tinderboxes. The data for 2025 alone is a sign of things to come.
# SOA=> Wildfires continue to test firefighters and locals across Europe as
# ###SOA Matches: 1 : [<re.Match object; span=(797, 864), match='Wildfires continue to test firefighters and local>]
# Saved: ../data/news_content/20250823/Environment_A_cruel_summer_as_record_wildfires_scorch_Europe.txt
# Fetching: India is ahead in clean energy commitments, achieves 2030 goal five years early => https://timesofindia.indiatimes.com/home/environment/india-is-ahead-in-clean-energy-commitments-achieves-2030-goal-five-years-early/articleshow/123325593.cms
# Description/Summary=>Marking Independence Day celebrations, the Prime Minister announced and hailed the achievement as a pivotal step towards an Atmanirbhar Bharat in the energy sector, underscoring the country's transformation from a fossil-fuel-dependent importer to a global clean energy leader.
# SOA=> Marking Independence Day celebrations, the Prime Minister announced and hailed
# ###SOA Matches: 2 : [<re.Match object; span=(1583, 1661), match='Marking Independence Day celebrations, the Prime >, <re.Match object; span=(2230, 2308), match='Marking Independence Day celebrations, the Prime >]
# Saved: ../data/news_content/20250823/Environment_India_is_ahead_in_clean_energy_commitments__achiev.txt
# Fetching: 150 species saved in England, but 'time running out' to halt decline => https://timesofindia.indiatimes.com/world/uk/150-species-saved-in-england-but-time-running-out-to-halt-decline/articleshow/123301794.cms
# Description/Summary=>A multi-million pound conservation programme in England helped save 150 struggling species but "time is running out" to halt the decline, the head of Natural England, which led the initiative, said Wednesday. But time is running out fast," he added.
# SOA=> A multi-million pound conservation programme in England helped save 150
# ###SOA Matches: 2 : [<re.Match object; span=(871, 942), match='A multi-million pound conservation programme in E>, <re.Match object; span=(1150, 1221), match='A multi-million pound conservation programme in E>]
# Saved: ../data/news_content/20250823/Environment_150_species_saved_in_England__but__time_running_ou.txt
# Fetching: Typhoon Podul intensifies as its near Taiwan => https://timesofindia.indiatimes.com/world/rest-of-world/typhoon-podul-intensifies-as-its-near-taiwan/articleshow/123292339.cms
# Description/Summary=>Typhoon Podul crossed southern Taiwan, prompting school and office closures due to heavy rain and potential agricultural damage. While no major damage was reported in Taiwan, one person is missing on the east coast. In China, coastal provinces evacuated around 15,000 residents as the storm moved towards the Taiwan Strait, impacting flights and regions south of Taipei.
# SOA=> Typhoon Podul crossed southern Taiwan, prompting school and office closures
# ###SOA Matches: 1 : [<re.Match object; span=(1474, 1549), match='Typhoon Podul crossed southern Taiwan, prompting >]
# Saved: ../data/news_content/20250823/Environment_Typhoon_Podul_intensifies_as_its_near_Taiwan.txt
# Fetching: Momentum sagging at UN plastic pollution treaty talks => https://timesofindia.indiatimes.com/home/environment/pollution/momentum-sagging-at-un-plastic-pollution-treaty-talks/articleshow/123213035.cms
# Description/Summary=>Talks on forging a landmark treaty to combat the scourge of plastic pollution were stumbling Saturday, with progress slow and countries wildly at odds on how far the proposed agreement should go. The talks are mandated to look at the full life cycle of plastic, from production to pollution, but some countries are unhappy with such a wide scope.
# SOA=> Talks on forging a landmark treaty to combat the scourge
# ###SOA Matches: 2 : [<re.Match object; span=(1505, 1561), match='Talks on forging a landmark treaty to combat the >, <re.Match object; span=(1881, 1937), match='Talks on forging a landmark treaty to combat the >]
# Saved: ../data/news_content/20250823/Environment_Momentum_sagging_at_UN_plastic_pollution_treaty_ta.txt
# Fetching: Climate heat extremes driving tropical bird decline: study => https://timesofindia.indiatimes.com/world/europe/climate-heat-extremes-driving-tropical-bird-decline-study/articleshow/123292473.cms
# Description/Summary=>Tropical bird populations have plummeted not only due to deforestation but also extreme heat attributable to climate change, according to a study published on Monday in the journal Nature Ecology & Evolution.  Another study published in 2017 showed how some tropical hummingbirds are now forced to seek shade to regulate their temperature in extreme heat, cutting into the amount of time they can spend searching for life-sustaining nectar.
# SOA=> Tropical bird populations have plummeted not only due to deforestation
# ###SOA Matches: 2 : [<re.Match object; span=(1542, 1612), match='Tropical bird populations have plummeted not only>, <re.Match object; span=(2012, 2082), match='Tropical bird populations have plummeted not only>]
# Saved: ../data/news_content/20250823/Environment_Climate_heat_extremes_driving_tropical_bird_declin.txt
# Fetching: Turkey reports hottest July in 55 years => https://timesofindia.indiatimes.com/home/environment/turkey-reports-hottest-july-in-55-years/articleshow/123204182.cms
# Description/Summary=>
# SOA=> Turkey reports hottest July in 55 years
# ###SOA Matches: 3 : [<re.Match object; span=(0, 39), match='Turkey reports hottest July in 55 years'>, <re.Match object; span=(1322, 1361), match='Turkey reports hottest July in 55 years'>, <re.Match object; span=(1361, 1400), match='Turkey reports hottest July in 55 years'>]
# Saved: ../data/news_content/20250823/Environment_Turkey_reports_hottest_July_in_55_years.txt
# Fetching: Fire in southern France burns 11,000 hectares, injures nine => https://timesofindia.indiatimes.com/world/europe/fire-in-southern-france-burns-11000-hectares-injures-nine/articleshow/123132842.cms
# ...
# SOA=> iQoo set to launch Z9 Turbo with 1.5K display, Snapdragon
# ###SOA Matches: 2 : [<re.Match object; span=(1159, 1216), match='iQoo set to launch Z9 Turbo with 1.5K display, Sn>, <re.Match object; span=(1322, 1379), match='iQoo set to launch Z9 Turbo with 1.5K display, Sn>]
# Saved: ../data/news_content/20250823/Tech_iQoo_Z9_Turbo_new_leak_reveals_key_specifications.txt
# Fetching: Samsung Galaxy A35 5G, Galaxy A55 5G price revealed => https://timesofindia.indiatimes.com/gadgets-news/samsung-galaxy-a35-5g-galaxy-a55-5g-india-price-revealed/articleshow/108482530.cms
# Description/Summary=>
# SOA=> Samsung Galaxy A35 5G, Galaxy A55 5G price revealed
# ###SOA Matches: 3 : [<re.Match object; span=(0, 51), match='Samsung Galaxy A35 5G, Galaxy A55 5G price reveal>, <re.Match object; span=(285, 336), match='Samsung Galaxy A35 5G, Galaxy A55 5G price reveal>, <re.Match object; span=(881, 932), match='Samsung Galaxy A35 5G, Galaxy A55 5G price reveal>]
# Saved: ../data/news_content/20250823/Tech_Samsung_Galaxy_A35_5G__Galaxy_A55_5G_price_reveale.txt
# Fetching: Government issues warning for these Android smartphone and tablet users => https://timesofindia.indiatimes.com/gadgets-news/government-issues-warning-for-these-android-smartphone-and-tablet-users/articleshow/108471249.cms
# Description/Summary=>The Indian CERT-In warns Android users of 'High' severity security flaws in multiple versions of the operating system, including vulnerabilities that could lead to obtaining sensitive information, gaining elevated privileges, executing arbitrary code, and causing denial of service conditions.
# SOA=> The Indian CERT-In warns Android users of 'High' severity security
# ###SOA Matches: 2 : [<re.Match object; span=(1115, 1181), match="The Indian CERT-In warns Android users of 'High' >, <re.Match object; span=(1409, 1475), match="The Indian CERT-In warns Android users of 'High' >]
# Saved: ../data/news_content/20250823/Tech_Government_issues_warning_for_these_Android_smartp.txt
# Fetching: You can now watch Ayodhya Ram Mandir morning Aarti live daily => https://timesofindia.indiatimes.com/gadgets-news/you-can-now-watch-ayodhya-ram-mandir-morning-aarti-live-daily/articleshow/108461881.cms
# Description/Summary=>Doordarshan will telecast live the Mangala, Shringaar, Rajbhog, Sandhya, and Shayan Aartis offered to the Ram Lalla idol at the Ayodhya Ram temple on DD National, connecting devotees who can't visit the temple.
# SOA=> Doordarshan will telecast live the Mangala, Shringaar, Rajbhog, Sandhya, and
# ###SOA Matches: 2 : [<re.Match object; span=(1100, 1176), match='Doordarshan will telecast live the Mangala, Shrin>, <re.Match object; span=(1311, 1387), match='Doordarshan will telecast live the Mangala, Shrin>]
# Saved: ../data/news_content/20250823/Tech_You_can_now_watch_Ayodhya_Ram_Mandir_morning_Aarti.txt
# Fetching: ChatGPT was down globally, here’s what the company has to say => https://timesofindia.indiatimes.com/gadgets-news/chatgpt-was-down-globally-heres-what-the-company-has-to-say/articleshow/108443030.cms
# Description/Summary=>ChatGPT experienced an outage, with 91% of users facing issues. OpenAI acknowledged the problem, and the service is now back online with performance back to normal. The TOI Tech team verified the restoration on the website and mobile app.
# SOA=> ChatGPT experienced an outage, with 91% of users facing issues.
# ###SOA Matches: 2 : [<re.Match object; span=(1085, 1148), match='ChatGPT experienced an outage, with 91% of users >, <re.Match object; span=(1324, 1387), match='ChatGPT experienced an outage, with 91% of users >]
# Saved: ../data/news_content/20250823/Tech_ChatGPT_was_down_globally__here_s_what_the_company.txt
# Fetching: Microsoft plans to take on iPhone and Android smartphones with this new device => https://timesofindia.indiatimes.com/gadgets-news/microsoft-plans-to-take-on-iphone-and-android-smartphones-with-this-new-device/articleshow/108439136.cms
# Description/Summary=>Microsoft discontinues Surface Duo smartphones but files a patent for a new foldable device with a single hinge system called 'spine cover plate'. The design aims to eliminate the hinge crease and reduce the device's thickness while offering added benefits and durability. However, its practicality remains uncertain.
# SOA=> Microsoft discontinues Surface Duo smartphones but files a patent for
# ###SOA Matches: 2 : [<re.Match object; span=(1112, 1181), match='Microsoft discontinues Surface Duo smartphones bu>, <re.Match object; span=(1430, 1499), match='Microsoft discontinues Surface Duo smartphones bu>]
# Saved: ../data/news_content/20250823/Tech_Microsoft_plans_to_take_on_iPhone_and_Android_smar.txt
# Fetching: Twitter bans over 5 lakh accounts in India, here's why => https://timesofindia.indiatimes.com/gadgets-news/twitter-bans-over-5-lakh-accounts-in-india-heres-why/articleshow/108438736.cms
# Description/Summary=>Elon Musk's X platform banned over 5 lakh Indian accounts for violating policies, including promoting terrorism and child sexual exploitation. Users should avoid violating policies to prevent account suspension.
# SOA=> Elon Musk's X platform banned over 5 lakh Indian accounts
# ###SOA Matches: 2 : [<re.Match object; span=(1076, 1133), match="Elon Musk's X platform banned over 5 lakh Indian >, <re.Match object; span=(1288, 1345), match="Elon Musk's X platform banned over 5 lakh Indian >]
# Saved: ../data/news_content/20250823/Tech_Twitter_bans_over_5_lakh_accounts_in_India__here_s.txt
# Fetching: 3 ways Google aims to support the 2024 Indian General Elections => https://timesofindia.indiatimes.com/gadgets-news/google-gets-ready-for-elections-in-india-with-new-features-and-more/articleshow/108432040.cms
# Description/Summary=>Google supports the Indian General Election by providing easy access to voting information and countering misinformation. Initiatives include partnering with the Election Commission, prioritizing trusted content on YouTube, and implementing advertising policies for transparency. Measures against AI-generated content are also taken.
# SOA=> Google supports the Indian General Election by providing easy access
# ###SOA Matches: 2 : [<re.Match object; span=(1093, 1161), match='Google supports the Indian General Election by pr>, <re.Match object; span=(1427, 1495), match='Google supports the Indian General Election by pr>]
# Saved: ../data/news_content/20250823/Tech_3_ways_Google_aims_to_support_the_2024_Indian_Gene.txt
# Fetching: This new AI tool can help you book train tickets, get refunds and check details on IRCTC website and app => https://timesofindia.indiatimes.com/gadgets-news/this-new-ai-tool-can-help-you-book-train-tickets-get-refunds-and-check-details-on-irctc-website-and-app/articleshow/108431623.cms
# Description/Summary=>Indian Railways' AI chatbot, AskDisha 2.0, powered by CoRover.AI, offers a range of services like booking tickets, refunds, checking PNR status, cancelling tickets, changing boarding station, checking booking history, and accessing e-tickets via text or voice commands in multiple languages.
# SOA=> Indian Railways' AI chatbot, AskDisha 2.0, powered by CoRover.AI, offers
# ###SOA Matches: 1 : [<re.Match object; span=(1159, 1231), match="Indian Railways' AI chatbot, AskDisha 2.0, powere>]
# Saved: ../data/news_content/20250823/Tech_This_new_AI_tool_can_help_you_book_train_tickets.txt
# Fetching: Chipmaker TSMC returns to the list of world's 10 most valuable companies: Here’s what led to its comeback => https://timesofindia.indiatimes.com/gadgets-news/chipmaker-tsmc-returns-to-the-list-of-worlds-10-most-valuable-companies-heres-what-led-to-its-comeback/articleshow/108393783.cms
# Description/Summary=>Taiwan Semiconductor Manufacturing Company (TSMC) has reclaimed a spot in the list of the world’s 10 most valuable companies, riding the optimism of the artificial intelligence (AI) boom. TSMC's stock rallied, elevating its market capitalisation to a record, making it higher than Broadcom. Analysts expect TSMC to further advance amid surging AI-related revenue and strong pricing power.
# SOA=> Taiwan Semiconductor Manufacturing Company (TSMC) has reclaimed a spot in
# ###SOA Matches: 0 : []
# list index out of range
# $$$$ Not able to process SOA for  Taiwan Semiconductor Manufacturing Company (TSMC) has reclaimed a spot in
# === Ignoring the news content as of now ===
# Fetching: Google Maps to get better with directions with future updates, here’s what’s changing => https://timesofindia.indiatimes.com/gadgets-news/google-maps-to-get-better-with-directions-with-future-updates-heres-whats-changing/articleshow/108392934.cms
# Description/Summary=>Google Maps is updating its Fused Orientation Provider (FOP) API to improve direction accuracy in busy areas. The update combines gyroscope, accelerometer, and magnetometer data, reducing magnetic interference and benefiting Google Maps and third-party apps on Android 5.0 or above.
# SOA=> Google Maps is updating its Fused Orientation Provider (FOP) API
# ###SOA Matches: 0 : []
# list index out of range
# $$$$ Not able to process SOA for  Google Maps is updating its Fused Orientation Provider (FOP) API
# === Ignoring the news content as of now ===
# Fetching: This popular YouTuber's account got hacked: What happened and tips to safeguard your account => https://timesofindia.indiatimes.com/gadgets-news/this-popular-youtubers-account-got-hacked-what-happened-and-tips-to-safeguard-your-account/articleshow/108392866.cms
# Description/Summary=>
# SOA=> This popular YouTuber's account got hacked: What happened and tips
# ###SOA Matches: 3 : [<re.Match object; span=(0, 66), match="This popular YouTuber's account got hacked: What >, <re.Match object; span=(326, 392), match="This popular YouTuber's account got hacked: What >, <re.Match object; span=(921, 987), match="This popular YouTuber's account got hacked: What >]
# Saved: ../data/news_content/20250823/Tech_This_popular_YouTuber_s_account_got_hacked__What_h.txt
# Fetching: Elon Musk’s AI company will make Grok chatbot more accessible, here’s how => https://timesofindia.indiatimes.com/gadgets-news/elon-musks-ai-company-will-make-grok-chatbot-more-accessible-heres-how/articleshow/108392239.cms
# Description/Summary=>Elon Musk criticizes OpenAI's deviation from mission and advocates AI accessibility for all. Musk announces xAI open sourcing Grok chatbot. OpenAI CEO Altman takes a dig at Musk's chatbot. Musk, obviously didn't like the jab and replied with a long-ish message saying “GPT-4 is about as funny as a screendoor on a submarine.”
# SOA=> Elon Musk criticizes OpenAI's deviation from mission and advocates AI
# ###SOA Matches: 1 : [<re.Match object; span=(1097, 1166), match="Elon Musk criticizes OpenAI's deviation from miss>]
# Saved: ../data/news_content/20250823/Tech_Elon_Musk_s_AI_company_will_make_Grok_chatbot_more.txt
# Fetching: Moto G54 receives a price cut in India: Here’s how much the smartphone costs => https://timesofindia.indiatimes.com/gadgets-news/moto-g54-receives-a-price-cut-in-india-heres-how-much-the-smartphone-costs/articleshow/108392072.cms
# Description/Summary=>The Moto G54 budget smartphone, with two variants, has received a price cut. The 8GB version is priced at Rs 13,999, and the 12GB variant is selling at Rs 15,999. It features a 6.5-inch FHD+ display, 120Hz refresh rate, and a 50MP main sensor.
# SOA=> The Moto G54 budget smartphone, with two variants, has received
# ###SOA Matches: 1 : [<re.Match object; span=(1106, 1169), match='The Moto G54 budget smartphone, with two variants>]
# Saved: ../data/news_content/20250823/Tech_Moto_G54_receives_a_price_cut_in_India__Here_s_how.txt
# Fetching: How Apple’s Find My app ‘cost’ a US city millions of dollars => https://timesofindia.indiatimes.com/gadgets-news/how-apples-find-my-app-cost-a-us-city-millions-of-dollars/articleshow/108374148.cms
# Description/Summary=>Denver city pays $3.76 million in damages due to a wrongful raid caused by Apple's Find My app. An elderly woman's home was mistakenly raided by the police while searching for a stolen truck loaded with guns, ammo, and cash, as reported by CNN. Ruby Johnson filed a lawsuit against Detective Gary Staab and Sgt. Gregory Buschy.
# SOA=> Denver city pays $3.76 million in damages due to a
# ###SOA Matches: 0 : []
# list index out of range
# $$$$ Not able to process SOA for  Denver city pays $3.76 million in damages due to a
# === Ignoring the news content as of now ===
# Fetching: Former Activision boss reportedly wants to buy TikTok => https://timesofindia.indiatimes.com/gadgets-news/former-activision-boss-reportedly-wants-to-buy-tiktok/articleshow/108390971.cms
# Description/Summary=>Bobby Kotick, former head of Activision Blizzard, may buy TikTok amid its potential US ban. A bill to sell TikTok is introduced, backed by President Biden. Kotick discussed acquisition with OpenAI head. Activision Blizzard faced a lawsuit. Concerns about data privacy and ties to China persist. TikTok urges American users to support it.
# SOA=> Bobby Kotick, former head of Activision Blizzard, may buy TikTok
# ###SOA Matches: 1 : [<re.Match object; span=(1037, 1101), match='Bobby Kotick, former head of Activision Blizzard,>]
# Saved: ../data/news_content/20250823/Tech_Former_Activision_boss_reportedly_wants_to_buy_Tik.txt
# Fetching: Why Earth Sciences minister Rijiju is upset with this European IT company => https://timesofindia.indiatimes.com/gadgets-news/why-earth-sciences-minister-rijiju-is-upset-with-this-european-it-company/articleshow/108390810.cms
# Description/Summary=>
# SOA=> Why Earth Sciences minister Rijiju is upset with this European
# ###SOA Matches: 3 : [<re.Match object; span=(14, 76), match='Why Earth Sciences minister Rijiju is upset with >, <re.Match object; span=(260, 322), match='Why Earth Sciences minister Rijiju is upset with >, <re.Match object; span=(938, 1000), match='Why Earth Sciences minister Rijiju is upset with >]
# Saved: ../data/news_content/20250823/Tech_Why_Earth_Sciences_minister_Rijiju_is_upset_with_t.txt
# Education => https://timesofindia.indiatimes.com//rssfeeds/913168846.cms
# ../data/news_content/20250823
# Fetching: Why will India not have any new law college in the coming three years? => https://timesofindia.indiatimes.com/education/news/why-will-india-not-have-any-new-law-college-in-the-coming-three-years/articleshow/123454347.cms
# Description/Summary=>The Bar Council of India has imposed a three-year moratorium on new law colleges due to concerns about declining educational standards and an oversupply of graduates. This pause aims to allow for audits, stricter regulations, and curriculum reforms to improve the quality of legal education. Exceptions may be considered for underserved regions, signalling a calibrated approach to address systemic issues.
# SOA=> The Bar Council of India has imposed a three-year moratorium
# ###SOA Matches: 1 : [<re.Match object; span=(1333, 1393), match='The Bar Council of India has imposed a three-year>]
# Saved: ../data/news_content/20250823/Education_Why_will_India_not_have_any_new_law_college_in_the.txt
# Fetching: 7 effective note-taking techniques that actually work => https://timesofindia.indiatimes.com/education/news/7-effective-note-taking-techniques-that-actually-work/articleshow/123404687.cms
# Description/Summary=>Effective note-taking is a crucial skill for students, emphasizing active listening, processing information, and using techniques like the Cornell method and visual thinking. Experts recommend revisiting notes within 24 hours to reinforce memory and transforming notes into personal dialogues with questions and insights. Ultimately, good notes spark curiosity and deepen understanding, making knowledge truly one's own.
# SOA=> Effective note-taking is a crucial skill for students, emphasizing active
# ###SOA Matches: 1 : [<re.Match object; span=(1301, 1374), match='Effective note-taking is a crucial skill for stud>]
# Saved: ../data/news_content/20250823/Education_7_effective_note-taking_techniques_that_actually_w.txt
# ../data/news_content/20250823

# %%
print(f"From {rss_feed_base_url} Successfull downloaded {rss_feed_count} news feeds from {rss_feed_urls_count} URLs.")
# Out:
# From https://timesofindia.indiatimes.com/ Successfull downloaded [74] news feeds from 5 URLs.
